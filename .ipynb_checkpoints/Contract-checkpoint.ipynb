# %%
import random
import string

# %%
def random_address():
    return '0x' + ''.join(random.choices('0123456789abcdef', k=40))

# %%
class Addressable:
    def __init__(self):
        self.address =  random_address()
