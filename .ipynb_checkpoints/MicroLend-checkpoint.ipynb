# %%
# %run 'Contract.ipynb'
# %run 'Token.ipynb'
# %run 'User.ipynb'

# %%
class MicroLend(Addressable):
    def __init__(
        self,
        lending_asset,
        collateral_assets,
        min_collat_ratio
    ):
        self.lending_asset     = lending_asset
        self.collateral_assets = collateral_assets
        min_collat_ratio       = min_collat_ratio

    def deposit(self, amount): pass

    def withdraw(self, amount): pass

    def collat_ratio(self): pass

# %%
mL = MicroLend(
    DYAD, 
    [USDC, WETH, WBTC, USDT],
    1.5                       # 150%
)
